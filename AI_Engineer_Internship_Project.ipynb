# %% [markdown]
# <a href="https://colab.research.google.com/github/rushibyna132/AI-Student-Study-Assistant/blob/main/AI_Engineer_Internship_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q# AI Student Study Assistant
#
# An AI-powered study assistant that helps college students learn and revise using Google Gemini AI.
#
# ### Features
# - Explain concepts
# - Summarize study notes
# - Generate quizzes
# - Create flashcards

# %% [markdown]
# ## Project Description
#
# The AI Student Study Assistant is a simple AI-powered application designed to help college students with learning and revision.
#
# It uses the Google Gemini API to generate useful study content based on the student's input.
#
# The application provides explanations, summaries, quizzes, and flashcards through a simple Gradio interface.

# %% [markdown]
# ## How It Works
#
# 1. The student selects a study feature.
# 2. The student enters a topic or study notes.
# 3. The application creates a structured prompt.
# 4. The prompt is sent to the Google Gemini AI model.
# 5. The generated result is displayed through the Gradio interface.
# 6. Basic validation and error handling provide a smoother user experience.

# %% [markdown]
# ## Technologies Used
#
# - Python
# - Google Gemini API
# - Google GenAI Python SDK
# - Gradio
# - Google Colab

# %% [markdown]
# ## Features
#
# ### 1. Explain
# Explains a topic in simple language with examples and key points.
#
# ### 2. Summarize
# Converts study notes into concise bullet points for quick revision.
#
# ### 3. Quiz
# Generates 5 multiple-choice questions with answers and explanations.
#
# ### 4. Flashcards
# Creates 5 question-and-answer flashcards for exam revision.

# %%
from google import genai

print("Gemini library is ready!")
# Out:
# Gemini library is ready!

# %%
# !pip -q install -U google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 2.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.7/259.7 kB 13.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires google-auth==2.49.0, but you have google-auth 2.57.0 which is incompatible.

# %%
from google import genai
from getpass import getpass

api_key = getpass("Enter your Gemini API key: ")

client = genai.Client(api_key=api_key)

print("Gemini connected successfully!")
# Out:
# Enter your Gemini API key: ··········
# Gemini connected successfully!

# %%
question = input("Enter your study question: ")

if question.strip() == "":
    print("Please enter a question.")
else:
    response = client.models.generate_content(
        model="gemini-3.6-flash",
        contents=question
    )

    print("\nAI Answer:")
    print(response.text)
# Out:
# Enter your study question: Python
#
# AI Answer:
# **Python** is one of the most popular, high-level, and versatile programming languages in the world. It is known for its clean, readable syntax, making it ideal for beginners while remaining powerful enough for complex professional applications.
#
# ---
#
# ### Key Features of Python
# * **Easy to Read & Learn:** Python’s syntax resembles natural English, reducing the cost of program maintenance.
# * **Interpreted:** Code is executed line-by-line, which makes debugging easier.
# * **Dynamically Typed:** You don't need to declare variable types explicitly (e.g., `x = 5` automatically knows `x` is an integer).
# * **Vast Ecosystem:** Thousands of third-party libraries and packages are available via `pip` (Python Package Index).
#
# ---
#
# ### Common Use Cases
#
# 1. **Data Science & Machine Learning**
#    * *Tools:* `pandas`, `NumPy`, `matplotlib`, `scikit-learn`, `PyTorch`, `TensorFlow`
# 2. **Web Development**
#    * *Frameworks:* Django, Flask, FastAPI
# 3. **Automation & Scripting**
#    * Automating repetitive tasks, web scraping (`BeautifulSoup`, `Selenium`)
# 4. **Software Development & Testing**
#    * Building desktop apps (`Tkinter`, `PyQt`), writing automated tests (`pytest`)
#
# ---
#
# ### Quick Example
#
# ```python
# # Basic syntax example
# def greet(name):
#     return f"Hello, {name}!"
#
# # Using a list comprehension
# numbers = [1, 2, 3, 4, 5]
# squared = [n ** 2 for n in numbers]
#
# print(greet("World"))
# print(f"Squared numbers: {squared}")
# ```
#
# ---
#
# ### How can I help you with Python today?
#
# * **Learning Python:** Explain concepts (loops, functions, OOP, async).
# * **Code Support:** Help write, refactor, or debug code.
# * **Data & AI:** Data analysis, visualization, or machine learning pipelines.
# * **Web & APIs:** Setting up web applications or REST APIs.
# * **Project Ideas:** Guidance on building a specific tool or app.

# %%
def study_assistant(feature, content):

    try:
        if feature == "Explain":
            prompt = f"""
You are an AI study assistant for college students.

Explain the topic in simple, easy-to-understand language.

Include:
1. Simple definition
2. Detailed explanation
3. Real-world example
4. Key points
5. Short exam-ready summary

Topic:
{content}
"""

        elif feature == "Summarize":
            prompt = f"""
You are an AI study assistant for college students.

Summarize the following study notes for quick revision.

Include:
1. Main points
2. Important definitions
3. Key concepts
4. Important facts
5. Short revision summary

Use clear bullet points.

Study Notes:
{content}
"""

        elif feature == "Quiz":
            prompt = f"""
You are an AI study assistant.

Create 5 multiple-choice questions about the topic.

For each question:
- Give 4 options (A, B, C, D)
- Clearly show the correct answer
- Give a short explanation of the answer

Topic:
{content}
"""

        elif feature == "Flashcards":
            prompt = f"""
You are an AI study assistant.

Create 5 study flashcards about the topic.

Format each flashcard as:

Flashcard 1
Question:
Answer:

Keep the questions useful for college exam revision.

Topic:
{content}
"""

        response = client.models.generate_content(
            model="gemini-3.6-flash",
            contents=prompt
        )

        return response.text

    except Exception as e:
        return "Sorry, something went wrong. Please try again."

# %%
print("===== AI STUDY ASSISTANT =====")
print("1. Explain a Concept")
print("2. Summarize Notes")
print("3. Generate a Quiz")

choice = input("\nChoose an option (1-3): ")

if choice == "1":
    feature = "Explain"
    content = input("Enter the topic you want explained: ")

elif choice == "2":
    feature = "Summarize"
    content = input("Paste your study notes: ")

elif choice == "3":
    feature = "Quiz"
    content = input("Enter the topic for the quiz: ")

else:
    print("Invalid choice. Please select 1, 2, or 3.")
    content = ""

if content.strip() != "":
    result = study_assistant(feature, content)

    print("\n===== AI OUTPUT =====")
    print(result)
# Out:
# ===== AI STUDY ASSISTANT =====
# 1. Explain a Concept
# 2. Summarize Notes
# 3. Generate a Quiz
#
# Choose an option (1-3): 1
# Enter the topic you want explained: Python
#
# ===== AI OUTPUT =====
# Hey there! As your study assistant, I’ve broken down **Python** into a clear, student-friendly guide to help you prep for your assignments or exams.
#
# ---
#
# ### 1. Simple Definition
# **Python** is a high-level, general-purpose programming language designed to be easy to read and write.
#
# Think of Python as the "English" of programming languages—instead of forcing you to write complex computer code, its syntax (rules) looks very close to natural human language.
#
# ---
#
# ### 2. Detailed Explanation
#
# To really understand Python, it helps to break down its core characteristics:
#
# *   **High-Level Language:** Computers only understand binary (`0`s and `1`s). Low-level languages (like Assembly or C) require you to write code closer to how the hardware thinks. Python is "high-level," meaning it handles complex tasks like memory management behind the scenes so you can focus on writing logic.
# *   **Interpreted Language:** Python reads and runs your code line-by-line using an *interpreter*. You don't need to manually compile your whole program into a file before testing it. If there’s an error on line 5, it runs lines 1 through 4 first, then tells you exactly where it got stuck.
# *   **Dynamically Typed:** In languages like Java or C++, you have to declare what kind of data a variable holds (e.g., "This is an integer," "This is text"). In Python, you just write `x = 5` or `x = "Hello"`, and Python automatically figures it out.
# *   **"Batteries Included" (Rich Ecosystem):** Python comes with tons of built-in tools, plus thousands of free, pre-written code packages (*libraries*) created by other developers. Whether you want to build a website, train an AI model, or create a graph, a library already exists to do heavy lifting for you (e.g., *Pandas, TensorFlow, Django*).
#
# ---
#
# ### 3. Real-World Example
#
# Imagine you work for **Netflix**, and you need to build a recommendation system that suggests movies based on what a user previously watched.
#
# 1.  **Data Collection:** You use Python to automatically pull a user's watch history.
# 2.  **Analysis:** You use a Python library called `Pandas` to analyze millions of other users with similar watch habits.
# 3.  **Machine Learning:** You use a Python AI library called `scikit-learn` to predict the top 3 movies this user will enjoy next.
# 4.  **Display:** You push these recommendations directly to the user's screen.
#
# Instead of writing thousands of lines of complex hardware code to do this math, Python lets engineers do it in just a few dozen lines using pre-built tools.
#
# ---
#
# ### 4. Key Points to Remember
#
# *   **Indentation Matters:** Unlike languages that use curly braces `{ }` to group code, Python uses **indentation (whitespace)** to define code blocks. Incorrect spacing will cause an error!
# *   **Multi-Purpose:** Python is used everywhere—Web Development, Data Science, Artificial Intelligence (AI), Cyber Security, and Task Automation.
# *   **Open Source:** It is 100% free to use, download, and modify.
# *   **Cross-Platform:** Python code written on a Mac will run on Windows or Linux without major changes.
#
# ---
#
# ### 5. Short Exam-Ready Summary
#
# > **Exam Definition:**
# > Python is an **open-source, high-level, interpreted, dynamically-typed** programming language known for its **readable syntax** and reliance on **indentation** for code blocks. It supports multiple programming paradigms and is extensively used in **data science, web development, AI, and automation** due to its vast library ecosystem.

# %%
# !pip -q install gradio

# %%
import gradio as gr

def run_assistant(feature, content):
    if content.strip() == "":
        return "Please enter a topic or study notes."

    return study_assistant(feature, content)


app = gr.Interface(
    fn=run_assistant,
    inputs=[
        gr.Dropdown(
            ["Explain", "Summarize", "Quiz", "Flashcards"],
            label="Choose a Study Feature"
        ),
        gr.Textbox(
            label="Enter Topic or Study Notes",
            placeholder="Type your topic or paste your notes here...",
            lines=6
        )
    ],
    outputs=gr.Textbox(label="AI Output"),
    title="🎓 AI Student Study Assistant",
    description="Learn, revise, and test your knowledge with AI."
)

app.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4c079d620570da98e9.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4c079d620570da98e9.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
